# %% [markdown]
# # Podobieństwo cząstkowe ciągów
#
#
# Dla dwóch ciągów znaków definiujemy podobieństwo jako długość najdłuższego wspólnego prefiksu dla obu ciągów. Np. podobieństwo ciągów "abc" i "abd" wyniosi 2, natomiast podobieństwo ciągów "aaa" oraz "aaab" wynosi 3. Otrzymując na wejściu ciąg znaków S oblicz sumę podobieństw ciągu S do wszystkich jego sufiksów. Przykładowe rozwiązanie:
#
# Wejście:
# ababaa
#
# Wyjście: 11 (6+0+3+0+1+1)

# %%
from aal import PrefixSum
import pandas as pd
import seaborn as sns
from io import StringIO

# %%
df =pd.read_csv("out.txt")

# %%
df.head(-5)
# Out:
#         n  N^2:t(n)[ms]  N^2:q(n)   N^2:sum  N:t(n)[ms]  N:q(n)     N:sum
# 0    1000          6.56      1.08    531847        0.90    1.02    531847
# 1    1500         13.79      1.01   1161559        1.22    0.92   1161559
# 2    2000         24.21      1.00   2051872        1.69    0.96   2051872
# 3    2500         37.63      0.99   3197980        2.30    1.04   3197980
# 4    3000         53.77      0.99   4580987        2.62    0.99   4580987
# 5    3500         72.97      0.98   6229403        3.20    1.04   6229403
# 6    4000         94.08      0.97   8110994        3.48    0.99   8110994
# 7    4500        119.73      0.98  10255176        3.96    1.00  10255176
# 8    5000        147.09      0.97  12636483        4.26    0.97  12636483
# 9    5500        180.69      0.99  15289024        4.74    0.98  15289024
# 10   6000        220.37      1.01  18182653        5.36    1.01  18182653
# 11   6500        254.96      1.00  21317326        5.84    1.02  21317326
# 12   7000        293.30      0.99  24704496        6.22    1.01  24704496
# 13   7500        335.16      0.98  28306026        7.16    1.08  28306026
# 14   8000        374.13      0.97  32283529        7.25    1.03  32283529
# 15   8500        437.55      1.00  36416099        7.50    1.00  36416099
# 16   9000        492.12      1.00  40797782        9.36    1.18  40797782
# 17   9500        558.59      1.02  45380946        9.86    1.18  45380946
# 18  10000        597.29      0.99  50302444        8.64    0.98  50302444
# 19  10500        662.03      0.99  55372973        8.82    0.95  55372973
# 20  11000        714.65      0.98  60758731        9.79    1.01  60758731
# 21  11500        784.25      0.98  66435947        9.97    0.98  66435947
# 22  12000        854.49      0.98  72372406       10.80    1.02  72372406
# 23  12500        929.59      0.98  78570013       11.44    1.04  78570013
# 24  13000       1012.69      0.99  84863689       11.57    1.01  84863689

# %%
show = pd.DataFrame()
show["n_size"]=df.n.append(df.n)
zloz =["O(N^2)"]*len(df.n)+["O(N)"]*len(df.n)
show["Złożoność"] = zloz
time =df.loc[:,"N^2:t(n)[ms]"].append(df.loc[:,"N:t(n)[ms]"])
show["time[ms]"] = time
show.head()
# Out:
#    n_size Złożoność  time[ms]
# 0    1000    O(N^2)      6.56
# 1    1500    O(N^2)     13.79
# 2    2000    O(N^2)     24.21
# 3    2500    O(N^2)     37.63
# 4    3000    O(N^2)     53.77

# %%
sns.lineplot(x="n_size",y="time[ms]", hue="Złożoność", data=show)
